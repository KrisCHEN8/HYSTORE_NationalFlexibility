# %%
import pandas as pd
import os

# %%
coutry = 'SE'      # Change with other coutries' abbreviations, e.g. ESP, SE, AUT  # noqa: E501
pickle_path = './national_zones/pickled_df'

df_demand = pd.read_pickle(os.path.join(pickle_path, 'df_demand.pkl'))
df_demand = df_demand[['Sweden_heating_kWh', 'Sweden_cooling_kWh']]

# %%
display(df_demand)
# Out:
#                      Sweden_heating_kWh  Sweden_cooling_kWh
# datetime
# 2022-01-01 00:00:00         2648043.582                   0
# 2022-01-01 01:00:00         2687395.613                   0
# 2022-01-01 02:00:00         2689021.657                   0
# 2022-01-01 03:00:00         2708687.503                   0
# 2022-01-01 04:00:00         2728921.757                   0
# ...                                 ...                 ...
# 2022-12-31 19:00:00         2827923.639                   0
# 2022-12-31 20:00:00         2867069.584                   0
# 2022-12-31 21:00:00         2864037.235                   0
# 2022-12-31 22:00:00         2869925.077                   0
# 2022-12-31 23:00:00         2912854.646                   0
#
# [8760 rows x 2 columns]

# %%
df_demand.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
df_agg = pd.read_pickle(os.path.join(pickle_path, f'df_agg_{coutry}.pkl'))

# %%
display(df_agg)
# Out:
#                      surplus_all  surplus_RES  Actual load
# 2022-01-01 00:00:00          0.0          0.0      15438.0
# 2022-01-01 01:00:00          0.0          0.0      15331.0
# 2022-01-01 02:00:00         15.0          0.0      15331.0
# 2022-01-01 03:00:00         80.0         41.0      15270.0
# 2022-01-01 04:00:00        117.0         78.0      15150.0
# ...                          ...          ...          ...
# 2022-12-31 19:00:00       2203.0       2120.0      15825.0
# 2022-12-31 20:00:00       2102.0       2025.0      15250.0
# 2022-12-31 21:00:00       2431.0       2362.0      14440.0
# 2022-12-31 22:00:00       2514.0       2419.0      14201.0
# 2022-12-31 23:00:00       2674.0       2585.0      13713.0
#
# [8760 rows x 3 columns]

# %%
df_agg['surplus_RES'].plot()
# Out:
# <Axes: >
